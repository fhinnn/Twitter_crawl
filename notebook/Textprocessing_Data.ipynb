# %% [markdown]
# ## Text Processing

# %% [markdown]
# Import Library

# %%
# !pip install demoji

# %%
import pandas as pd
import nltk
import numpy
import re
import demoji
import nltk
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/danielpepuho/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# Upload Dataset

# %%
url = 'https://drive.google.com/uc?id=1pdaeJ0ThUJcuFmrUzeN_U8ZCApG1yBmT'
df_pemilu = pd.read_csv(url)
df_pemilu.head(15)
# Out:
#           ID                                             Tweets  \
# 0   1,66E+18  Sama dok, saya gerah juga lihat kelakuan yg ja...
# 1   1,66E+18  Otak kotor itu capresmu Ganjar, capres hobby n...
# 2   1,66E+18  Kwalitas Anies memang diatas 2 capres lainnya....
# 3   1,66E+18  Laaaa enak tooo liatnya, capres no jaim, yang ...
# 4   1,66E+18  Setujuu.. mereka Oligardan ingin capres boneka...
# 5   1,66E+18  Norak lu Den,...apa yang dilakukan Ganjar suda...
# 6   1,66E+18  Bukan siapa Presidennya, melainkan siapa wakil...
# 7   1,66E+18  Contoh capres yang gak suka selfie dan posting...
# 8   1,66E+18  Pa Jokowi hanya menyebut 2 nama capres ..yaitu...
# 9   1,66E+18  Media2 nasional dgn nama besar semakin busuk. ...
# 10  1,66E+18          Dari pada capres anda gagal pimpin Jateng
# 11  1,66E+18  Bolehkah oposisi menyiapkan capres? Boleh saja...
# 12  1,66E+18                             SBY mau jadi capres y?
# 13  1,66E+18  Kurang relevan sih dikaitkan dengan sitkon pol...
# ...

# %% [markdown]
# Case Folding pada Text Dataset

# %%
df_pemilu['Tweets'] = df_pemilu['Tweets'].apply(lambda x: x.lower())
df_pemilu.head(15)
# Out:
#           ID                                             Tweets  \
# 0   1,66E+18  sama dok, saya gerah juga lihat kelakuan yg ja...
# 1   1,66E+18  otak kotor itu capresmu ganjar, capres hobby n...
# 2   1,66E+18  kwalitas anies memang diatas 2 capres lainnya....
# 3   1,66E+18  laaaa enak tooo liatnya, capres no jaim, yang ...
# 4   1,66E+18  setujuu.. mereka oligardan ingin capres boneka...
# 5   1,66E+18  norak lu den,...apa yang dilakukan ganjar suda...
# 6   1,66E+18  bukan siapa presidennya, melainkan siapa wakil...
# 7   1,66E+18  contoh capres yang gak suka selfie dan posting...
# 8   1,66E+18  pa jokowi hanya menyebut 2 nama capres ..yaitu...
# 9   1,66E+18  media2 nasional dgn nama besar semakin busuk. ...
# 10  1,66E+18          dari pada capres anda gagal pimpin jateng
# 11  1,66E+18  bolehkah oposisi menyiapkan capres? boleh saja...
# 12  1,66E+18                             sby mau jadi capres y?
# 13  1,66E+18  kurang relevan sih dikaitkan dengan sitkon pol...
# ...

# %% [markdown]
# Fungi tokenize

# %%
def clean_text(text):
    cleaned_text = re.sub(r'[^\w\s]', '', text)
    return cleaned_text

def tokenize_text(text):
    tokens = word_tokenize(text)
    tokens_with_quotes = ['"' + token + '"' for token in tokens]
    return tokens_with_quotes

# %%
df_pemilu['Tweets'] = df_pemilu['Tweets'].apply(clean_text)
df_pemilu['Tweets'] = df_pemilu['Tweets'].apply(tokenize_text)
df_pemilu.head(50)
# Out:
#           ID                                             Tweets  \
# 0   1,66E+18  ["sama", "dok", "saya", "gerah", "juga", "liha...
# 1   1,66E+18  ["otak", "kotor", "itu", "capresmu", "ganjar",...
# 2   1,66E+18  ["kwalitas", "anies", "memang", "diatas", "2",...
# 3   1,66E+18  ["laaaa", "enak", "tooo", "liatnya", "capres",...
# 4   1,66E+18  ["setujuu", "mereka", "oligardan", "ingin", "c...
# 5   1,66E+18  ["norak", "lu", "denapa", "yang", "dilakukan",...
# 6   1,66E+18  ["bukan", "siapa", "presidennya", "melainkan",...
# 7   1,66E+18  ["contoh", "capres", "yang", "gak", "suka", "s...
# 8   1,66E+18  ["pa", "jokowi", "hanya", "menyebut", "2", "na...
# 9   1,66E+18  ["media2", "nasional", "dgn", "nama", "besar",...
# 10  1,66E+18  ["dari", "pada", "capres", "anda", "gagal", "p...
# 11  1,66E+18  ["bolehkah", "oposisi", "menyiapkan", "capres"...
# 12  1,66E+18              ["sby", "mau", "jadi", "capres", "y"]
# 13  1,66E+18  ["kurang", "relevan", "sih", "dikaitkan", "den...
# ...

# %% [markdown]
# Stemming

# %%
# %pip install sastrawi
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
#from nltk.stem import PorterStemmer

# %%
#stemmer = PorterStemmer()

# %%
# def stemming_text(text):
#     tokens = word_tokenize(text)
#     stemmed_tokens = [stemmer.stem(token) for token in tokens]
#     stemmed_text = ' '.join(stemmed_tokens)
#     return stemmed_text

# %%
# # Mengonversi tipe data kolom 'Tweets' menjadi string
# df_pemilu['Tweets'] = df_pemilu['Tweets'].astype(str)
# # Menerapkan stemming pada kolom 'Tweets'
# df_pemilu['Tweets'] = df_pemilu['Tweets'].apply(stemming_text)

# %%
# df_pemilu.head(50)
# Out:
#           ID                                             Tweets  \
# 0   1,66E+18  [ ' `` sama `` ' , ' `` dok `` ' , ' `` saya `...
# 1   1,66E+18  [ ' `` otak `` ' , ' `` kotor `` ' , ' `` itu ...
# 2   1,66E+18  [ ' `` kwalita `` ' , ' `` ani `` ' , ' `` mem...
# 3   1,66E+18  [ ' `` laaaa `` ' , ' `` enak `` ' , ' `` tooo...
# 4   1,66E+18  [ ' `` setujuu `` ' , ' `` mereka `` ' , ' `` ...
# 5   1,66E+18  [ ' `` norak `` ' , ' `` lu `` ' , ' `` denapa...
# 6   1,66E+18  [ ' `` bukan `` ' , ' `` siapa `` ' , ' `` pre...
# 7   1,66E+18  [ ' `` contoh `` ' , ' `` capr `` ' , ' `` yan...
# 8   1,66E+18  [ ' `` pa `` ' , ' `` jokowi `` ' , ' `` hanya...
# 9   1,66E+18  [ ' `` media2 `` ' , ' `` nasion `` ' , ' `` d...
# 10  1,66E+18  [ ' `` dari `` ' , ' `` pada `` ' , ' `` capr ...
# 11  1,66E+18  [ ' `` bolehkah `` ' , ' `` oposisi `` ' , ' `...
# 12  1,66E+18  [ ' `` sbi `` ' , ' `` mau `` ' , ' `` jadi ``...
# 13  1,66E+18  [ ' `` kurang `` ' , ' `` relevan `` ' , ' `` ...
# ...
