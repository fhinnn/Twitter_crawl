# %% [markdown]
# ## Text Processing

# %% [markdown]
# Import Library

# %%
# %pip install demoji
# %pip install sastrawi
# Out:
# Requirement already satisfied: demoji in /usr/local/lib/python3.10/dist-packages (1.1.0)
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
import pandas as pd
import nltk
import numpy
import re
import demoji
import nltk
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory # steeming

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = nltk.corpus.stopwords.words('indonesian')

# %% [markdown]
# Read Dataset from Google drive

# %%
path = '/content/final_pemilu.csv'
df_pemilu = pd.read_csv(path)
df_pemilu[["Tweets", "Anotator 1", "Anotator 2", "Anotator 3", "Hasil"]].head(20)
# Out:
#                                                Tweets  Anotator 1  Anotator 2  \
# 0   Sama dok, saya gerah juga lihat kelakuan yg ja...        -1.0        -1.0
# 1   Otak kotor itu capresmu Ganjar, capres hobby n...        -1.0        -1.0
# 2   Kwalitas Anies memang diatas 2 capres lainnya....         1.0         1.0
# 3   Laaaa enak tooo liatnya, capres no jaim, yang ...         1.0         1.0
# 4   Setujuu.. mereka Oligardan ingin capres boneka...        -1.0        -1.0
# 5   Norak lu Den,...apa yang dilakukan Ganjar suda...        -1.0        -1.0
# 6   Bukan siapa Presidennya, melainkan siapa wakil...        -1.0         1.0
# 7   Contoh capres yang gak suka selfie dan posting...         1.0         1.0
# 8   Pa Jokowi hanya menyebut 2 nama capres ..yaitu...        -1.0        -1.0
# 9   Media2 nasional dgn nama besar semakin busuk. ...        -1.0        -1.0
# 10          Dari pada capres anda gagal pimpin Jateng        -1.0        -1.0
# 11  Bolehkah oposisi menyiapkan capres? Boleh saja...         0.0        -1.0
# 12                             SBY mau jadi capres y?         0.0         0.0
# 13  Kurang relevan sih dikaitkan dengan sitkon pol...         0.0         0.0
# 14                         SBY mau maju ya jd capres?         1.0         0.0
# 15                        Udah bisa lah jadi capres 🤣         0.0         0.0
# 16  Pagi prof...\nKlo bisa di usulin..nanti pas de...         1.0         1.0
# 17  Berarti presiden sekarang sibuk nya lagi nguru...        -1.0        -1.0
# 18  Sungguh keterlaluan kalau capres yang punya ke...        -1.0        -1.0
# 19           punchline yg duarr banget pak capres\n😃👍         1.0         1.0
#
#     Anotator 3  Hasil
# 0         -1.0   -1.0
# 1         -1.0   -1.0
# 2         -1.0    1.0
# 3          1.0    1.0
# 4         -1.0   -1.0
# 5         -1.0   -1.0
# 6         -1.0   -1.0
# 7          1.0    1.0
# 8         -1.0   -1.0
# 9         -1.0   -1.0
# 10        -1.0   -1.0
# 11         0.0    0.0
# 12         0.0    0.0
# 13         0.0    0.0
# 14         0.0    0.0
# 15         0.0    0.0
# 16         1.0    1.0
# 17        -1.0   -1.0
# 18        -1.0   -1.0
# 19         0.0    1.0

# %% [markdown]
# Case Folding pada Text Dataset

# %%
df_pemilu['Tweets'] = df_pemilu['Tweets'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df_pemilu[["Tweets", "Anotator 1", "Anotator 2", "Anotator 3", "Hasil"]].head(20)
# Out:
#                                                Tweets  Anotator 1  Anotator 2  \
# 0   sama dok, saya gerah juga lihat kelakuan yg ja...        -1.0        -1.0
# 1   otak kotor itu capresmu ganjar, capres hobby n...        -1.0        -1.0
# 2   kwalitas anies memang diatas 2 capres lainnya....         1.0         1.0
# 3   laaaa enak tooo liatnya, capres no jaim, yang ...         1.0         1.0
# 4   setujuu.. mereka oligardan ingin capres boneka...        -1.0        -1.0
# 5   norak lu den,...apa yang dilakukan ganjar suda...        -1.0        -1.0
# 6   bukan siapa presidennya, melainkan siapa wakil...        -1.0         1.0
# 7   contoh capres yang gak suka selfie dan posting...         1.0         1.0
# 8   pa jokowi hanya menyebut 2 nama capres ..yaitu...        -1.0        -1.0
# 9   media2 nasional dgn nama besar semakin busuk. ...        -1.0        -1.0
# 10          dari pada capres anda gagal pimpin jateng        -1.0        -1.0
# 11  bolehkah oposisi menyiapkan capres? boleh saja...         0.0        -1.0
# 12                             sby mau jadi capres y?         0.0         0.0
# 13  kurang relevan sih dikaitkan dengan sitkon pol...         0.0         0.0
# 14                         sby mau maju ya jd capres?         1.0         0.0
# 15                        udah bisa lah jadi capres 🤣         0.0         0.0
# 16  pagi prof...\nklo bisa di usulin..nanti pas de...         1.0         1.0
# 17  berarti presiden sekarang sibuk nya lagi nguru...        -1.0        -1.0
# 18  sungguh keterlaluan kalau capres yang punya ke...        -1.0        -1.0
# 19           punchline yg duarr banget pak capres\n😃👍         1.0         1.0
#
#     Anotator 3  Hasil
# 0         -1.0   -1.0
# 1         -1.0   -1.0
# 2         -1.0    1.0
# 3          1.0    1.0
# 4         -1.0   -1.0
# 5         -1.0   -1.0
# 6         -1.0   -1.0
# 7          1.0    1.0
# 8         -1.0   -1.0
# 9         -1.0   -1.0
# 10        -1.0   -1.0
# 11         0.0    0.0
# 12         0.0    0.0
# 13         0.0    0.0
# 14         0.0    0.0
# 15         0.0    0.0
# 16         1.0    1.0
# 17        -1.0   -1.0
# 18        -1.0   -1.0
# 19         0.0    1.0

# %% [markdown]
# Fungi tokenize

# %%
def clean_text(text):
    try:
        cleaned_text = re.sub(r'[^\w\s]', '', text)
        return cleaned_text
    except Exception as e:
        print(f"An error occurred during text cleaning: {e}")
        return ""

def tokenize_text(text):
    # Check if the input is a string, if not, return an empty list
    if not isinstance(text, str):
        return []

    try:
        tokens = word_tokenize(text)
        tokens_with_quotes = ['"' + token + '"' for token in tokens]
        return tokens_with_quotes
    except Exception as e:
        print(f"An error occurred during tokenization: {e}")
        return []

# %%
df_pemilu['Tweets'] = df_pemilu['Tweets'].apply(clean_text)
df_pemilu['Tweets'] = df_pemilu['Tweets'].apply(tokenize_text)
# Out:
# An error occurred during text cleaning: expected string or bytes-like object

# %%
df_pemilu[["Tweets", "Anotator 1", "Anotator 2", "Anotator 3", "Hasil"]].head(20)
# Out:
#                                                Tweets  Anotator 1  Anotator 2  \
# 0   ["sama", "dok", "saya", "gerah", "juga", "liha...        -1.0        -1.0
# 1   ["otak", "kotor", "itu", "capresmu", "ganjar",...        -1.0        -1.0
# 2   ["kwalitas", "anies", "memang", "diatas", "2",...         1.0         1.0
# 3   ["laaaa", "enak", "tooo", "liatnya", "capres",...         1.0         1.0
# 4   ["setujuu", "mereka", "oligardan", "ingin", "c...        -1.0        -1.0
# 5   ["norak", "lu", "denapa", "yang", "dilakukan",...        -1.0        -1.0
# 6   ["bukan", "siapa", "presidennya", "melainkan",...        -1.0         1.0
# 7   ["contoh", "capres", "yang", "gak", "suka", "s...         1.0         1.0
# 8   ["pa", "jokowi", "hanya", "menyebut", "2", "na...        -1.0        -1.0
# 9   ["media2", "nasional", "dgn", "nama", "besar",...        -1.0        -1.0
# 10  ["dari", "pada", "capres", "anda", "gagal", "p...        -1.0        -1.0
# 11  ["bolehkah", "oposisi", "menyiapkan", "capres"...         0.0        -1.0
# 12              ["sby", "mau", "jadi", "capres", "y"]         0.0         0.0
# 13  ["kurang", "relevan", "sih", "dikaitkan", "den...         0.0         0.0
# 14       ["sby", "mau", "maju", "ya", "jd", "capres"]         1.0         0.0
# 15          ["udah", "bisa", "lah", "jadi", "capres"]         0.0         0.0
# 16  ["pagi", "prof", "klo", "bisa", "di", "usulinn...         1.0         1.0
# 17  ["berarti", "presiden", "sekarang", "sibuk", "...        -1.0        -1.0
# 18  ["sungguh", "keterlaluan", "kalau", "capres", ...        -1.0        -1.0
# 19  ["punchline", "yg", "duarr", "banget", "pak", ...         1.0         1.0
#
#     Anotator 3  Hasil
# 0         -1.0   -1.0
# 1         -1.0   -1.0
# 2         -1.0    1.0
# 3          1.0    1.0
# 4         -1.0   -1.0
# 5         -1.0   -1.0
# 6         -1.0   -1.0
# 7          1.0    1.0
# 8         -1.0   -1.0
# 9         -1.0   -1.0
# 10        -1.0   -1.0
# 11         0.0    0.0
# 12         0.0    0.0
# 13         0.0    0.0
# 14         0.0    0.0
# 15         0.0    0.0
# 16         1.0    1.0
# 17        -1.0   -1.0
# 18        -1.0   -1.0
# 19         0.0    1.0

# %% [markdown]
# ## Stemming text

# %%
def stem_text(tokens):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    stemmed_tokens = [f'"{stemmer.stem(token)}"' for token in tokens]
    filtered_tokens = [token for token in stemmed_tokens if token.lower() not in stopwords]  # Stopword removal
    return filtered_tokens

# %%
df_pemilu_subset = df_pemilu.head(20).copy()
df_pemilu_subset['Tweets'] = df_pemilu_subset['Tweets'].apply(stem_text)

# %%
df_pemilu[["Tweets", "Anotator 1", "Anotator 2", "Anotator 3", "Hasil"]].head(20)
# Out:
#                                                Tweets  Anotator 1  Anotator 2  \
# 0   ["sama", "dok", "saya", "gerah", "juga", "liha...        -1.0        -1.0
# 1   ["otak", "kotor", "itu", "capresmu", "ganjar",...        -1.0        -1.0
# 2   ["kwalitas", "anies", "memang", "diatas", "2",...         1.0         1.0
# 3   ["laaaa", "enak", "tooo", "liatnya", "capres",...         1.0         1.0
# 4   ["setujuu", "mereka", "oligardan", "ingin", "c...        -1.0        -1.0
# 5   ["norak", "lu", "denapa", "yang", "dilakukan",...        -1.0        -1.0
# 6   ["bukan", "siapa", "presidennya", "melainkan",...        -1.0         1.0
# 7   ["contoh", "capres", "yang", "gak", "suka", "s...         1.0         1.0
# 8   ["pa", "jokowi", "hanya", "menyebut", "2", "na...        -1.0        -1.0
# 9   ["media2", "nasional", "dgn", "nama", "besar",...        -1.0        -1.0
# 10  ["dari", "pada", "capres", "anda", "gagal", "p...        -1.0        -1.0
# 11  ["bolehkah", "oposisi", "menyiapkan", "capres"...         0.0        -1.0
# 12              ["sby", "mau", "jadi", "capres", "y"]         0.0         0.0
# 13  ["kurang", "relevan", "sih", "dikaitkan", "den...         0.0         0.0
# 14       ["sby", "mau", "maju", "ya", "jd", "capres"]         1.0         0.0
# 15          ["udah", "bisa", "lah", "jadi", "capres"]         0.0         0.0
# 16  ["pagi", "prof", "klo", "bisa", "di", "usulinn...         1.0         1.0
# 17  ["berarti", "presiden", "sekarang", "sibuk", "...        -1.0        -1.0
# 18  ["sungguh", "keterlaluan", "kalau", "capres", ...        -1.0        -1.0
# 19  ["punchline", "yg", "duarr", "banget", "pak", ...         1.0         1.0
#
#     Anotator 3  Hasil
# 0         -1.0   -1.0
# 1         -1.0   -1.0
# 2         -1.0    1.0
# 3          1.0    1.0
# 4         -1.0   -1.0
# 5         -1.0   -1.0
# 6         -1.0   -1.0
# 7          1.0    1.0
# 8         -1.0   -1.0
# 9         -1.0   -1.0
# 10        -1.0   -1.0
# 11         0.0    0.0
# 12         0.0    0.0
# 13         0.0    0.0
# 14         0.0    0.0
# 15         0.0    0.0
# 16         1.0    1.0
# 17        -1.0   -1.0
# 18        -1.0   -1.0
# 19         0.0    1.0

# %% [markdown]
# Word Cloud
#
# referensi: https://www.datacamp.com/tutorial/wordcloud-python

# %%
# %pip install numpy scipy matplotlib nose pillow imageio imread
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: nose in /usr/local/lib/python3.10/dist-packages (1.3.7)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.25.1)
# Requirement already satisfied: imread in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'https://drive.google.com/uc?id=1pdaeJ0ThUJcuFmrUzeN_U8ZCApG1yBmT'
df_pemilu = pd.read_csv(url, encoding='ISO-8859-1',index_col=0)

# %%
# Looking at first 20 rows of the dataset
# Count number of tweets from dataset
df_pemilu.head(20)
num_tweets = df_pemilu.shape[0]

# %%
rows = len(df_pemilu.axes[0])
cols = len(df_pemilu.axes[1])

# %%
print(df_pemilu)
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
#                                                      Tweets           Tanggal  \
# ID
# 1,66E+18  Sama dok, saya gerah juga lihat kelakuan yg ja...  27/05/2023 23:55
# 1,66E+18  Otak kotor itu capresmu Ganjar, capres hobby n...  27/05/2023 23:55
# 1,66E+18  Kwalitas Anies memang diatas 2 capres lainnya....  27/05/2023 23:48
# 1,66E+18  Laaaa enak tooo liatnya, capres no jaim, yang ...  27/05/2023 23:48
# 1,66E+18  Setujuu.. mereka Oligardan ingin capres boneka...  27/05/2023 23:47
# ...                                                     ...               ...
# 1,63E+18  wkwkw....yg dibutuhkan rakyat bukan elektabili...   13/02/2023 9:10
# 1,63E+18  Jgn sampai terjadi dgn TDK memilih capres dr d...   13/02/2023 9:09
# 1,63E+18                        bukan capres, tapi cawapres   13/02/2023 9:09
# 1,63E+18                          Bang Anies capres terbaik   13/02/2023 9:05
# 1,63E+18  Lho kan udah tembus PT 20%?\nIni mau komunikas...   13/02/2023 9:02
#
#          Lokasi Bu ratih  Dhafin  Daniel
# ID
# 1,66E+18    NaN       -1    -1.0    -1.0
# 1,66E+18    NaN       -1    -1.0    -1.0
# 1,66E+18    NaN        1     1.0    -1.0
# 1,66E+18    NaN        1     1.0     1.0
# 1,66E+18    NaN       -1    -1.0    -1.0
# ...         ...      ...     ...     ...
# 1,63E+18    NaN      NaN     NaN    -1.0
# 1,63E+18    NaN      NaN     NaN     1.0
# 1,63E+18    NaN      NaN     NaN     0.0
# 1,63E+18    NaN      NaN     NaN     1.0
# 1,63E+18    NaN      NaN     NaN    -1.0
#
# [70673 rows x 6 columns]
# Number of Rows:  70673
# Number of Columns:  6

# %%
print("There are {} Tweets in this dataset.\n".format(num_tweets, df_pemilu.shape[0]))
# Out:
# There are 70673 Tweets in this dataset.

# %%
df_pemilu[["Tweets", "Tanggal"]].head(20)
# Out:
#                                                      Tweets           Tanggal
# ID
# 1,66E+18  Sama dok, saya gerah juga lihat kelakuan yg ja...  27/05/2023 23:55
# 1,66E+18  Otak kotor itu capresmu Ganjar, capres hobby n...  27/05/2023 23:55
# 1,66E+18  Kwalitas Anies memang diatas 2 capres lainnya....  27/05/2023 23:48
# 1,66E+18  Laaaa enak tooo liatnya, capres no jaim, yang ...  27/05/2023 23:48
# 1,66E+18  Setujuu.. mereka Oligardan ingin capres boneka...  27/05/2023 23:47
# 1,66E+18  Norak lu Den,...apa yang dilakukan Ganjar suda...  27/05/2023 23:47
# 1,66E+18  Bukan siapa Presidennya, melainkan siapa wakil...  27/05/2023 23:45
# 1,66E+18  Contoh capres yang gak suka selfie dan posting...  27/05/2023 23:43
# 1,66E+18  Pa Jokowi hanya menyebut 2 nama capres ..yaitu...  27/05/2023 23:41
# 1,66E+18  Media2 nasional dgn nama besar semakin busuk. ...  27/05/2023 23:39
# 1,66E+18          Dari pada capres anda gagal pimpin Jateng  27/05/2023 23:38
# 1,66E+18  Bolehkah oposisi menyiapkan capres? Boleh saja...  27/05/2023 23:35
# 1,66E+18                             SBY mau jadi capres y?  27/05/2023 23:34
# 1,66E+18  Kurang relevan sih dikaitkan dengan sitkon pol...  27/05/2023 23:34
# 1,66E+18                         SBY mau maju ya jd capres?  27/05/2023 23:33
# 1,66E+18                     Udah bisa lah jadi capres ð¤£  27/05/2023 23:27
# 1,66E+18  Pagi prof...\nKlo bisa di usulin..nanti pas de...  27/05/2023 23:23
# 1,66E+18  Berarti presiden sekarang sibuk nya lagi nguru...  27/05/2023 23:23
# 1,66E+18  Sungguh keterlaluan kalau capres yang punya ke...  27/05/2023 23:21
# 1,66E+18     punchline yg duarr banget pak capres\nðð  27/05/2023 23:13

# %%
# Groupby by tweets
tweets = df_pemilu.groupby("Tweets")

# %%
tweets.head()
# Out:
#                                                      Tweets           Tanggal  \
# ID
# 1,66E+18  Sama dok, saya gerah juga lihat kelakuan yg ja...  27/05/2023 23:55
# 1,66E+18  Otak kotor itu capresmu Ganjar, capres hobby n...  27/05/2023 23:55
# 1,66E+18  Kwalitas Anies memang diatas 2 capres lainnya....  27/05/2023 23:48
# 1,66E+18  Laaaa enak tooo liatnya, capres no jaim, yang ...  27/05/2023 23:48
# 1,66E+18  Setujuu.. mereka Oligardan ingin capres boneka...  27/05/2023 23:47
# ...                                                     ...               ...
# 1,63E+18  wkwkw....yg dibutuhkan rakyat bukan elektabili...   13/02/2023 9:10
# 1,63E+18  Jgn sampai terjadi dgn TDK memilih capres dr d...   13/02/2023 9:09
# 1,63E+18                        bukan capres, tapi cawapres   13/02/2023 9:09
# 1,63E+18                          Bang Anies capres terbaik   13/02/2023 9:05
# 1,63E+18  Lho kan udah tembus PT 20%?\nIni mau komunikas...   13/02/2023 9:02
#
#          Lokasi Bu ratih  Dhafin  Daniel
# ID
# 1,66E+18    NaN       -1    -1.0    -1.0
# 1,66E+18    NaN       -1    -1.0    -1.0
# 1,66E+18    NaN        1     1.0    -1.0
# 1,66E+18    NaN        1     1.0     1.0
# 1,66E+18    NaN       -1    -1.0    -1.0
# ...         ...      ...     ...     ...
# 1,63E+18    NaN      NaN     NaN    -1.0
# 1,63E+18    NaN      NaN     NaN     1.0
# 1,63E+18    NaN      NaN     NaN     0.0
# 1,63E+18    NaN      NaN     NaN     1.0
# 1,63E+18    NaN      NaN     NaN    -1.0
#
# [70673 rows x 6 columns]
